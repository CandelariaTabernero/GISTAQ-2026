# %% [markdown]
# Colocar una introducción sobre lo que trata el codigo, luego cargar librerias y especificar caracteristicas

# %% [markdown]
# Lectura de los archivos raster, lectura del vector utilizado para el recorte

# %% [markdown]
# Recortar, y transformar a reflactancia de superficie

# %% [markdown]
# Calcular MNDWI, calcular mascara de agua

# %% [markdown]
# Aplicar la mascara de agua a los demas raster

# %% [markdown]
# Calcular indices espectrales

# %% [markdown]
# Almacenar los raster, con indice y fecha

# %% [markdown]
# Hacer una represantación grafica del indice espectral analizado

# %% [markdown]
# Guardar la representación como png (mapa)
